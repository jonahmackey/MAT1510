# %% [markdown]
# **Goal**<br>
# The goal of this exercise is to generate the information plane studied in class for a multilayer perceptron trained on the MNIST dataset (projected to 12 dimensions using PCA).
#
# *Before you start, make sure to change the runtime type to include a GPU!*
#
# <br>
#
# **Task (adding two lines of code)**<br>
# Implement the calculation of the empirical mutual informations $\hat{I}(X;H)$ and $\hat{I}(Y;H)$.
#
# Hint: use the python functions sum and math.log2
#
# <br>
#
# **Submission**<br>
# *   Download your code by clicking File -> Download .ipynb
# *   Submit your downloaded code on Quercus

# %%
import math
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torchvision.models as models

from collections import Counter
from sklearn.decomposition import PCA
from torch.utils.data import TensorDataset
from torchvision import datasets, transforms

# %%
# hyperparameters
device        = 'cuda'
lr            = 7e-2
epochs        = 10
milestones    = [epochs//2]
gamma         = 0.5
batch_size    = 512
momentum      = 0
weight_decay  = 0
n_bins        = 10

# %%
# deep network
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(12, 10)
        self.fc2 = nn.Linear(10, 7)
        self.fc3 = nn.Linear(7, 5)
        self.fc4 = nn.Linear(5, 4)
        self.fc5 = nn.Linear(4, 3)
        self.fc6 = nn.Linear(3, 2)

    def forward(self, x):
        h1 = torch.tanh(self.fc1(x))
        h2 = torch.tanh(self.fc2(h1))
        h3 = torch.tanh(self.fc3(h2))
        h4 = torch.tanh(self.fc4(h3))
        h5 = torch.tanh(self.fc5(h4))
        h6 = F.log_softmax(self.fc6(h5), dim=1)
        return h1, h2, h3, h4, h5, h6

model = Model().to(device)

def process_dataset(dataset):
    # keep only images of two digits
    digit1 = 0
    digit2 = 2
    
    indices = (dataset.targets == digit1) | (dataset.targets == digit2)
    dataset.data, dataset.targets = dataset.data[indices], dataset.targets[indices]
    
    dataset.targets[dataset.targets == digit1] = 0
    dataset.targets[dataset.targets == digit2] = 1

    dataset = TensorDataset(dataset.data.reshape(-1, 28*28), dataset.targets)

    return dataset

transform = transforms.ToTensor()
train_dataset = process_dataset(datasets.MNIST('../data', download=True, train=True, transform=transform))
test_dataset = process_dataset(datasets.MNIST('../data', download=True, train=False, transform=transform))

# use PCA to reduce to 12 dimensions
pca = PCA(n_components=12)
pca.fit(train_dataset.tensors[0])
train_dataset.tensors = (torch.from_numpy(pca.transform(train_dataset.tensors[0])).float(), train_dataset.tensors[1])
test_dataset.tensors = (torch.from_numpy(pca.transform(test_dataset.tensors[0])).float(), test_dataset.tensors[1])

# dataset loaders
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)

train_loader_full = torch.utils.data.DataLoader(
    train_dataset, batch_size=len(train_loader.dataset), shuffle=False, drop_last=False)

test_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

# loss function
loss_function = nn.NLLLoss()

# optimizer
optimizer = optim.SGD(model.parameters(),
                      lr=lr,
                      momentum=momentum,
                      weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=gamma)

# %%
train_accuracy = []
test_accuracy = []

# mutual informations for every epoch and every layer
layers = len(list(model.children()))
MI_XH = torch.zeros(epochs, layers)
MI_YH = torch.zeros(epochs, layers)

# iterate over epochs
for epoch in range(epochs):
    # run model on full train dataset
    for images, labels in train_loader_full:
        images, labels = images.to(device), labels.to(device)

    h_list = model(images)

    # calculate mutual information
    for layer, h in enumerate(h_list):
        # discretize images and representations
        bins = np.linspace(0, 1, n_bins+1)
        x_ = np.digitize(images.cpu(), bins)
        if layer == layers-1:
            h = torch.exp(h)
            bins = np.linspace(0, 1, n_bins+1)
        else:
            bins = np.linspace(-1, 1, n_bins+1)
        h_ = np.digitize(h.cpu().detach().numpy(), bins)
        y_ = labels.cpu()

        # calculate discrete probabilities
        p_X = Counter()
        p_Y = Counter()
        p_H = Counter()
        p_XH = Counter()
        p_YH = Counter()
        
        for x_i, h_i, y_i in zip(x_, h_, y_):
            def totuple(a):
                try:
                    return tuple(totuple(i) for i in a)
                except:
                    return a.item()
            
            unit = 1./len(images)

            p_X[totuple(x_i)]                   += unit
            p_Y[totuple(y_i)]                   += unit
            p_H[totuple(h_i)]                   += unit
            p_XH[(totuple(x_i), totuple(h_i))]  += unit
            p_YH[(totuple(y_i), totuple(h_i))]  += unit

        # ADD CODE HERE
        MI_XH[epoch][layer] = sum([p_XH[(x, h)] * (math.log(p_XH[(x, h)]) - math.log(p_X[x]) - math.log(p_H[h])) for x, h in p_XH])
        MI_YH[epoch][layer] = sum([p_YH[(y, h)] * (math.log(p_YH[(y, h)]) - math.log(p_Y[y]) - math.log(p_H[h])) for y, h in p_YH])

    # train phase
    model.train()
    accuracy = 0
    N = 0
    
    # iterate over train data
    for batch_idx, (images, labels) in enumerate(train_loader, start=1):
        images, labels = images.to(device), labels.to(device)
        
        # forward pass
        h1, h2, h3, h4, h5, h6 = model(images)
        loss = loss_function(h6, labels)

        # backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # check if predicted labels are equal to true labels
        predicted_labels = torch.argmax(h6,dim=1)
        accuracy += torch.sum((predicted_labels==labels).float()).item()
        N += images.shape[0]

        print('Train\t\tEpoch: {} \t'
              'Batch {}/{} ({:.0f}%) \t'
              'Batch Loss: {:.6f} \t'
              'Batch Accuracy: {:.6f}'.format(
                  epoch+1,
                  batch_idx,
                  len(train_loader),
                  100. * batch_idx / len(train_loader),
                  loss.item(),
                  100. * accuracy/N))
        
    train_accuracy.append(100. * accuracy/N)
    
    scheduler.step()

    # test phase
    model.eval()
    accuracy = 0
    N = 0

    # iterate over test data
    for batch_idx, (images, labels) in enumerate(test_loader, start=1):
        images, labels = images.to(device), labels.to(device)

        # forward pass
        h1, h2, h3, h4, h5, h6 = model(images)
        
        # check if predicted labels are equal to true labels
        predicted_labels = torch.argmax(h6,dim=1)
        accuracy += torch.sum((predicted_labels==labels).float()).item()
        N += images.shape[0]
    test_accuracy.append(100. * accuracy/N)
    print(test_accuracy[-1])

# plot results
plt.figure()
plt.title('Accuracy Versus Epoch')
plt.plot(range(1, epochs+1), train_accuracy, label='Train')
plt.plot(range(1, epochs+1), test_accuracy, label='Test')
plt.legend()
plt.savefig("accuracy_vs_epoch.png")

plt.figure()
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xlabel('MI_X,H')
ax.set_ylabel('MI_Y,H')
title = ax.set_title('Information Plane')
cmap = plt.get_cmap('gnuplot', epochs)
colors = [cmap(i) for i in np.linspace(0, 1, epochs)]
ax.plot(MI_XH, MI_YH, '-', color='gray')
for layer in range(layers):
    im = ax.scatter(MI_XH[:,layer], MI_YH[:,layer], c=colors)

plt.savefig("information_plane.png")
# Out:
# Train		Epoch: 1 	Batch 1/23 (4%) 	Batch Loss: 0.705230 	Batch Accuracy: 48.437500
# Train		Epoch: 1 	Batch 2/23 (9%) 	Batch Loss: 0.694572 	Batch Accuracy: 50.195312
# Train		Epoch: 1 	Batch 3/23 (13%) 	Batch Loss: 0.700605 	Batch Accuracy: 49.934896
# Train		Epoch: 1 	Batch 4/23 (17%) 	Batch Loss: 0.697525 	Batch Accuracy: 50.048828
# Train		Epoch: 1 	Batch 5/23 (22%) 	Batch Loss: 0.696159 	Batch Accuracy: 50.156250
# Train		Epoch: 1 	Batch 6/23 (26%) 	Batch Loss: 0.706786 	Batch Accuracy: 49.316406
# Train		Epoch: 1 	Batch 7/23 (30%) 	Batch Loss: 0.690669 	Batch Accuracy: 49.804688
# Train		Epoch: 1 	Batch 8/23 (35%) 	Batch Loss: 0.693294 	Batch Accuracy: 50.000000
# Train		Epoch: 1 	Batch 9/23 (39%) 	Batch Loss: 0.697172 	Batch Accuracy: 49.869792
# Train		Epoch: 1 	Batch 10/23 (43%) 	Batch Loss: 0.694873 	Batch Accuracy: 49.863281
# Train		Epoch: 1 	Batch 11/23 (48%) 	Batch Loss: 0.695397 	Batch Accuracy: 49.804688
# Train		Epoch: 1 	Batch 12/23 (52%) 	Batch Loss: 0.697244 	Batch Accuracy: 49.609375
# Train		Epoch: 1 	Batch 13/23 (57%) 	Batch Loss: 0.691086 	Batch Accuracy: 49.744591
# Train		Epoch: 1 	Batch 14/23 (61%) 	Batch Loss: 0.690922 	Batch Accuracy: 49.874442
# Train		Epoch: 1 	Batch 15/23 (65%) 	Batch Loss: 0.695655 	Batch Accuracy: 49.726562
# Train		Epoch: 1 	Batch 16/23 (70%) 	Batch Loss: 0.693290 	Batch Accuracy: 49.694824
# Train		Epoch: 1 	Batch 17/23 (74%) 	Batch Loss: 0.693486 	Batch Accuracy: 49.643842
# Train		Epoch: 1 	Batch 18/23 (78%) 	Batch Loss: 0.694755 	Batch Accuracy: 49.500868
# Train		Epoch: 1 	Batch 19/23 (83%) 	Batch Loss: 0.689422 	Batch Accuracy: 49.660773
# Train		Epoch: 1 	Batch 20/23 (87%) 	Batch Loss: 0.690746 	Batch Accuracy: 49.716797
# Train		Epoch: 1 	Batch 21/23 (91%) 	Batch Loss: 0.690778 	Batch Accuracy: 49.758185
# Train		Epoch: 1 	Batch 22/23 (96%) 	Batch Loss: 0.689403 	Batch Accuracy: 49.857955
# Train		Epoch: 1 	Batch 23/23 (100%) 	Batch Loss: 0.690609 	Batch Accuracy: 49.864130
# 48.70775347912525
# Train		Epoch: 2 	Batch 1/23 (4%) 	Batch Loss: 0.690720 	Batch Accuracy: 49.609375
# Train		Epoch: 2 	Batch 2/23 (9%) 	Batch Loss: 0.691164 	Batch Accuracy: 49.316406
# Train		Epoch: 2 	Batch 3/23 (13%) 	Batch Loss: 0.689897 	Batch Accuracy: 49.869792
# Train		Epoch: 2 	Batch 4/23 (17%) 	Batch Loss: 0.691712 	Batch Accuracy: 49.267578
# Train		Epoch: 2 	Batch 5/23 (22%) 	Batch Loss: 0.692051 	Batch Accuracy: 48.750000
# Train		Epoch: 2 	Batch 6/23 (26%) 	Batch Loss: 0.688211 	Batch Accuracy: 49.511719
# Train		Epoch: 2 	Batch 7/23 (30%) 	Batch Loss: 0.691158 	Batch Accuracy: 49.079241
# Train		Epoch: 2 	Batch 8/23 (35%) 	Batch Loss: 0.690709 	Batch Accuracy: 48.925781
# Train		Epoch: 2 	Batch 9/23 (39%) 	Batch Loss: 0.688626 	Batch Accuracy: 49.305556
# Train		Epoch: 2 	Batch 10/23 (43%) 	Batch Loss: 0.688431 	Batch Accuracy: 49.628906
# Train		Epoch: 2 	Batch 11/23 (48%) 	Batch Loss: 0.688386 	Batch Accuracy: 49.893466
# Train		Epoch: 2 	Batch 12/23 (52%) 	Batch Loss: 0.686488 	Batch Accuracy: 50.358073
# Train		Epoch: 2 	Batch 13/23 (57%) 	Batch Loss: 0.688440 	Batch Accuracy: 50.345553
# Train		Epoch: 2 	Batch 14/23 (61%) 	Batch Loss: 0.690523 	Batch Accuracy: 50.111607
# Train		Epoch: 2 	Batch 15/23 (65%) 	Batch Loss: 0.687695 	Batch Accuracy: 50.169271
# Train		Epoch: 2 	Batch 16/23 (70%) 	Batch Loss: 0.688877 	Batch Accuracy: 50.000000
# Train		Epoch: 2 	Batch 17/23 (74%) 	Batch Loss: 0.688953 	Batch Accuracy: 49.954044
# Train		Epoch: 2 	Batch 18/23 (78%) 	Batch Loss: 0.687411 	Batch Accuracy: 50.716146
# Train		Epoch: 2 	Batch 19/23 (83%) 	Batch Loss: 0.688298 	Batch Accuracy: 51.120477
# Train		Epoch: 2 	Batch 20/23 (87%) 	Batch Loss: 0.686258 	Batch Accuracy: 52.060547
# Train		Epoch: 2 	Batch 21/23 (91%) 	Batch Loss: 0.687355 	Batch Accuracy: 52.427455
# Train		Epoch: 2 	Batch 22/23 (96%) 	Batch Loss: 0.687731 	Batch Accuracy: 52.876420
# Train		Epoch: 2 	Batch 23/23 (100%) 	Batch Loss: 0.687033 	Batch Accuracy: 53.388247
# 70.77534791252485
# Train		Epoch: 3 	Batch 1/23 (4%) 	Batch Loss: 0.687305 	Batch Accuracy: 67.968750
# Train		Epoch: 3 	Batch 2/23 (9%) 	Batch Loss: 0.686668 	Batch Accuracy: 73.535156
# Train		Epoch: 3 	Batch 3/23 (13%) 	Batch Loss: 0.686420 	Batch Accuracy: 74.869792
# Train		Epoch: 3 	Batch 4/23 (17%) 	Batch Loss: 0.685893 	Batch Accuracy: 75.732422
# Train		Epoch: 3 	Batch 5/23 (22%) 	Batch Loss: 0.684905 	Batch Accuracy: 76.250000
# Train		Epoch: 3 	Batch 6/23 (26%) 	Batch Loss: 0.684830 	Batch Accuracy: 76.562500
# Train		Epoch: 3 	Batch 7/23 (30%) 	Batch Loss: 0.685633 	Batch Accuracy: 76.450893
# Train		Epoch: 3 	Batch 8/23 (35%) 	Batch Loss: 0.685629 	Batch Accuracy: 76.489258
# Train		Epoch: 3 	Batch 9/23 (39%) 	Batch Loss: 0.684818 	Batch Accuracy: 76.822917
# Train		Epoch: 3 	Batch 10/23 (43%) 	Batch Loss: 0.684624 	Batch Accuracy: 76.582031
# Train		Epoch: 3 	Batch 11/23 (48%) 	Batch Loss: 0.684566 	Batch Accuracy: 77.041903
# Train		Epoch: 3 	Batch 12/23 (52%) 	Batch Loss: 0.683255 	Batch Accuracy: 77.457682
# Train		Epoch: 3 	Batch 13/23 (57%) 	Batch Loss: 0.684120 	Batch Accuracy: 77.539062
# Train		Epoch: 3 	Batch 14/23 (61%) 	Batch Loss: 0.681654 	Batch Accuracy: 77.929688
# Train		Epoch: 3 	Batch 15/23 (65%) 	Batch Loss: 0.683340 	Batch Accuracy: 78.177083
# Train		Epoch: 3 	Batch 16/23 (70%) 	Batch Loss: 0.682078 	Batch Accuracy: 78.381348
# Train		Epoch: 3 	Batch 17/23 (74%) 	Batch Loss: 0.682211 	Batch Accuracy: 78.458180
# Train		Epoch: 3 	Batch 18/23 (78%) 	Batch Loss: 0.681398 	Batch Accuracy: 78.233507
# Train		Epoch: 3 	Batch 19/23 (83%) 	Batch Loss: 0.681767 	Batch Accuracy: 78.433388
# Train		Epoch: 3 	Batch 20/23 (87%) 	Batch Loss: 0.679686 	Batch Accuracy: 78.769531
# Train		Epoch: 3 	Batch 21/23 (91%) 	Batch Loss: 0.679203 	Batch Accuracy: 78.962054
# Train		Epoch: 3 	Batch 22/23 (96%) 	Batch Loss: 0.680636 	Batch Accuracy: 79.039418
# Train		Epoch: 3 	Batch 23/23 (100%) 	Batch Loss: 0.678978 	Batch Accuracy: 79.177989
# 85.08946322067594
# Train		Epoch: 4 	Batch 1/23 (4%) 	Batch Loss: 0.679206 	Batch Accuracy: 84.570312
# Train		Epoch: 4 	Batch 2/23 (9%) 	Batch Loss: 0.679268 	Batch Accuracy: 83.984375
# Train		Epoch: 4 	Batch 3/23 (13%) 	Batch Loss: 0.677619 	Batch Accuracy: 83.398438
# Train		Epoch: 4 	Batch 4/23 (17%) 	Batch Loss: 0.678007 	Batch Accuracy: 83.740234
# Train		Epoch: 4 	Batch 5/23 (22%) 	Batch Loss: 0.675198 	Batch Accuracy: 84.453125
# Train		Epoch: 4 	Batch 6/23 (26%) 	Batch Loss: 0.675381 	Batch Accuracy: 84.472656
# Train		Epoch: 4 	Batch 7/23 (30%) 	Batch Loss: 0.674533 	Batch Accuracy: 84.737723
# Train		Epoch: 4 	Batch 8/23 (35%) 	Batch Loss: 0.673338 	Batch Accuracy: 84.667969
# Train		Epoch: 4 	Batch 9/23 (39%) 	Batch Loss: 0.672266 	Batch Accuracy: 84.809028
# Train		Epoch: 4 	Batch 10/23 (43%) 	Batch Loss: 0.673240 	Batch Accuracy: 84.648438
# Train		Epoch: 4 	Batch 11/23 (48%) 	Batch Loss: 0.672665 	Batch Accuracy: 84.765625
# Train		Epoch: 4 	Batch 12/23 (52%) 	Batch Loss: 0.671175 	Batch Accuracy: 84.977214
# Train		Epoch: 4 	Batch 13/23 (57%) 	Batch Loss: 0.669861 	Batch Accuracy: 85.201322
# Train		Epoch: 4 	Batch 14/23 (61%) 	Batch Loss: 0.668919 	Batch Accuracy: 85.239955
# Train		Epoch: 4 	Batch 15/23 (65%) 	Batch Loss: 0.667557 	Batch Accuracy: 85.052083
# Train		Epoch: 4 	Batch 16/23 (70%) 	Batch Loss: 0.666008 	Batch Accuracy: 85.241699
# Train		Epoch: 4 	Batch 17/23 (74%) 	Batch Loss: 0.665091 	Batch Accuracy: 85.259651
# Train		Epoch: 4 	Batch 18/23 (78%) 	Batch Loss: 0.663602 	Batch Accuracy: 85.416667
# Train		Epoch: 4 	Batch 19/23 (83%) 	Batch Loss: 0.662938 	Batch Accuracy: 85.413240
# Train		Epoch: 4 	Batch 20/23 (87%) 	Batch Loss: 0.663265 	Batch Accuracy: 85.351562
# Train		Epoch: 4 	Batch 21/23 (91%) 	Batch Loss: 0.662768 	Batch Accuracy: 85.342262
# Train		Epoch: 4 	Batch 22/23 (96%) 	Batch Loss: 0.658989 	Batch Accuracy: 85.431463
# Train		Epoch: 4 	Batch 23/23 (100%) 	Batch Loss: 0.656564 	Batch Accuracy: 85.538383
# 86.87872763419483
# Train		Epoch: 5 	Batch 1/23 (4%) 	Batch Loss: 0.657856 	Batch Accuracy: 85.937500
# Train		Epoch: 5 	Batch 2/23 (9%) 	Batch Loss: 0.652023 	Batch Accuracy: 86.816406
# Train		Epoch: 5 	Batch 3/23 (13%) 	Batch Loss: 0.651323 	Batch Accuracy: 86.783854
# Train		Epoch: 5 	Batch 4/23 (17%) 	Batch Loss: 0.650879 	Batch Accuracy: 86.083984
# Train		Epoch: 5 	Batch 5/23 (22%) 	Batch Loss: 0.649015 	Batch Accuracy: 86.054688
# Train		Epoch: 5 	Batch 6/23 (26%) 	Batch Loss: 0.644092 	Batch Accuracy: 86.555990
# Train		Epoch: 5 	Batch 7/23 (30%) 	Batch Loss: 0.640053 	Batch Accuracy: 86.997768
# Train		Epoch: 5 	Batch 8/23 (35%) 	Batch Loss: 0.639920 	Batch Accuracy: 87.109375
# Train		Epoch: 5 	Batch 9/23 (39%) 	Batch Loss: 0.630935 	Batch Accuracy: 87.586806
# Train		Epoch: 5 	Batch 10/23 (43%) 	Batch Loss: 0.636040 	Batch Accuracy: 87.519531
# Train		Epoch: 5 	Batch 11/23 (48%) 	Batch Loss: 0.625279 	Batch Accuracy: 87.819602
# Train		Epoch: 5 	Batch 12/23 (52%) 	Batch Loss: 0.625591 	Batch Accuracy: 87.825521
# Train		Epoch: 5 	Batch 13/23 (57%) 	Batch Loss: 0.617124 	Batch Accuracy: 88.161058
# Train		Epoch: 5 	Batch 14/23 (61%) 	Batch Loss: 0.616678 	Batch Accuracy: 88.127790
# Train		Epoch: 5 	Batch 15/23 (65%) 	Batch Loss: 0.611678 	Batch Accuracy: 88.333333
# Train		Epoch: 5 	Batch 16/23 (70%) 	Batch Loss: 0.613870 	Batch Accuracy: 88.293457
# Train		Epoch: 5 	Batch 17/23 (74%) 	Batch Loss: 0.603901 	Batch Accuracy: 88.327206
# Train		Epoch: 5 	Batch 18/23 (78%) 	Batch Loss: 0.593408 	Batch Accuracy: 88.476562
# Train		Epoch: 5 	Batch 19/23 (83%) 	Batch Loss: 0.586369 	Batch Accuracy: 88.630757
# Train		Epoch: 5 	Batch 20/23 (87%) 	Batch Loss: 0.582196 	Batch Accuracy: 88.789062
# Train		Epoch: 5 	Batch 21/23 (91%) 	Batch Loss: 0.577737 	Batch Accuracy: 88.895089
# Train		Epoch: 5 	Batch 22/23 (96%) 	Batch Loss: 0.562509 	Batch Accuracy: 89.026989
# Train		Epoch: 5 	Batch 23/23 (100%) 	Batch Loss: 0.563231 	Batch Accuracy: 89.087976
# 91.84890656063618
# Train		Epoch: 6 	Batch 1/23 (4%) 	Batch Loss: 0.547843 	Batch Accuracy: 92.968750
# Train		Epoch: 6 	Batch 2/23 (9%) 	Batch Loss: 0.549026 	Batch Accuracy: 92.187500
# Train		Epoch: 6 	Batch 3/23 (13%) 	Batch Loss: 0.538088 	Batch Accuracy: 92.447917
# Train		Epoch: 6 	Batch 4/23 (17%) 	Batch Loss: 0.539589 	Batch Accuracy: 92.138672
# Train		Epoch: 6 	Batch 5/23 (22%) 	Batch Loss: 0.529407 	Batch Accuracy: 92.148438
# Train		Epoch: 6 	Batch 6/23 (26%) 	Batch Loss: 0.525591 	Batch Accuracy: 92.089844
# Train		Epoch: 6 	Batch 7/23 (30%) 	Batch Loss: 0.523458 	Batch Accuracy: 92.047991
# Train		Epoch: 6 	Batch 8/23 (35%) 	Batch Loss: 0.522397 	Batch Accuracy: 91.967773
# Train		Epoch: 6 	Batch 9/23 (39%) 	Batch Loss: 0.507294 	Batch Accuracy: 92.144097
# Train		Epoch: 6 	Batch 10/23 (43%) 	Batch Loss: 0.504654 	Batch Accuracy: 92.226562
# Train		Epoch: 6 	Batch 11/23 (48%) 	Batch Loss: 0.493506 	Batch Accuracy: 92.382812
# Train		Epoch: 6 	Batch 12/23 (52%) 	Batch Loss: 0.500598 	Batch Accuracy: 92.285156
# Train		Epoch: 6 	Batch 13/23 (57%) 	Batch Loss: 0.488538 	Batch Accuracy: 92.307692
# Train		Epoch: 6 	Batch 14/23 (61%) 	Batch Loss: 0.489107 	Batch Accuracy: 92.299107
# Train		Epoch: 6 	Batch 15/23 (65%) 	Batch Loss: 0.480867 	Batch Accuracy: 92.278646
# Train		Epoch: 6 	Batch 16/23 (70%) 	Batch Loss: 0.477113 	Batch Accuracy: 92.260742
# Train		Epoch: 6 	Batch 17/23 (74%) 	Batch Loss: 0.472062 	Batch Accuracy: 92.210478
# Train		Epoch: 6 	Batch 18/23 (78%) 	Batch Loss: 0.465352 	Batch Accuracy: 92.220052
# Train		Epoch: 6 	Batch 19/23 (83%) 	Batch Loss: 0.465656 	Batch Accuracy: 92.187500
# Train		Epoch: 6 	Batch 20/23 (87%) 	Batch Loss: 0.450130 	Batch Accuracy: 92.177734
# Train		Epoch: 6 	Batch 21/23 (91%) 	Batch Loss: 0.436981 	Batch Accuracy: 92.271205
# Train		Epoch: 6 	Batch 22/23 (96%) 	Batch Loss: 0.436949 	Batch Accuracy: 92.329545
# Train		Epoch: 6 	Batch 23/23 (100%) 	Batch Loss: 0.435844 	Batch Accuracy: 92.348845
# 93.68787276341948
# Train		Epoch: 7 	Batch 1/23 (4%) 	Batch Loss: 0.422947 	Batch Accuracy: 93.554688
# Train		Epoch: 7 	Batch 2/23 (9%) 	Batch Loss: 0.425666 	Batch Accuracy: 93.164062
# Train		Epoch: 7 	Batch 3/23 (13%) 	Batch Loss: 0.415071 	Batch Accuracy: 93.359375
# Train		Epoch: 7 	Batch 4/23 (17%) 	Batch Loss: 0.405436 	Batch Accuracy: 93.652344
# Train		Epoch: 7 	Batch 5/23 (22%) 	Batch Loss: 0.402240 	Batch Accuracy: 93.750000
# Train		Epoch: 7 	Batch 6/23 (26%) 	Batch Loss: 0.403697 	Batch Accuracy: 93.587240
# Train		Epoch: 7 	Batch 7/23 (30%) 	Batch Loss: 0.385152 	Batch Accuracy: 93.666295
# Train		Epoch: 7 	Batch 8/23 (35%) 	Batch Loss: 0.386308 	Batch Accuracy: 93.676758
# Train		Epoch: 7 	Batch 9/23 (39%) 	Batch Loss: 0.379415 	Batch Accuracy: 93.771701
# Train		Epoch: 7 	Batch 10/23 (43%) 	Batch Loss: 0.384650 	Batch Accuracy: 93.671875
# Train		Epoch: 7 	Batch 11/23 (48%) 	Batch Loss: 0.363124 	Batch Accuracy: 93.732244
# Train		Epoch: 7 	Batch 12/23 (52%) 	Batch Loss: 0.363848 	Batch Accuracy: 93.750000
# Train		Epoch: 7 	Batch 13/23 (57%) 	Batch Loss: 0.373099 	Batch Accuracy: 93.599760
# Train		Epoch: 7 	Batch 14/23 (61%) 	Batch Loss: 0.361393 	Batch Accuracy: 93.596540
# Train		Epoch: 7 	Batch 15/23 (65%) 	Batch Loss: 0.350392 	Batch Accuracy: 93.697917
# Train		Epoch: 7 	Batch 16/23 (70%) 	Batch Loss: 0.335632 	Batch Accuracy: 93.798828
# Train		Epoch: 7 	Batch 17/23 (74%) 	Batch Loss: 0.347926 	Batch Accuracy: 93.761489
# Train		Epoch: 7 	Batch 18/23 (78%) 	Batch Loss: 0.345628 	Batch Accuracy: 93.771701
# Train		Epoch: 7 	Batch 19/23 (83%) 	Batch Loss: 0.341429 	Batch Accuracy: 93.811678
# Train		Epoch: 7 	Batch 20/23 (87%) 	Batch Loss: 0.316730 	Batch Accuracy: 93.837891
# Train		Epoch: 7 	Batch 21/23 (91%) 	Batch Loss: 0.318755 	Batch Accuracy: 93.889509
# Train		Epoch: 7 	Batch 22/23 (96%) 	Batch Loss: 0.314260 	Batch Accuracy: 93.945312
# Train		Epoch: 7 	Batch 23/23 (100%) 	Batch Loss: 0.325976 	Batch Accuracy: 93.902853
# 94.98011928429423
# Train		Epoch: 8 	Batch 1/23 (4%) 	Batch Loss: 0.305081 	Batch Accuracy: 94.335938
# Train		Epoch: 8 	Batch 2/23 (9%) 	Batch Loss: 0.308958 	Batch Accuracy: 94.042969
# Train		Epoch: 8 	Batch 3/23 (13%) 	Batch Loss: 0.294648 	Batch Accuracy: 94.531250
# Train		Epoch: 8 	Batch 4/23 (17%) 	Batch Loss: 0.293359 	Batch Accuracy: 94.677734
# Train		Epoch: 8 	Batch 5/23 (22%) 	Batch Loss: 0.299365 	Batch Accuracy: 94.609375
# Train		Epoch: 8 	Batch 6/23 (26%) 	Batch Loss: 0.286932 	Batch Accuracy: 94.661458
# Train		Epoch: 8 	Batch 7/23 (30%) 	Batch Loss: 0.285902 	Batch Accuracy: 94.614955
# Train		Epoch: 8 	Batch 8/23 (35%) 	Batch Loss: 0.269859 	Batch Accuracy: 94.750977
# Train		Epoch: 8 	Batch 9/23 (39%) 	Batch Loss: 0.281692 	Batch Accuracy: 94.683160
# Train		Epoch: 8 	Batch 10/23 (43%) 	Batch Loss: 0.274841 	Batch Accuracy: 94.746094
# Train		Epoch: 8 	Batch 11/23 (48%) 	Batch Loss: 0.287199 	Batch Accuracy: 94.620028
# Train		Epoch: 8 	Batch 12/23 (52%) 	Batch Loss: 0.260782 	Batch Accuracy: 94.759115
# Train		Epoch: 8 	Batch 13/23 (57%) 	Batch Loss: 0.261187 	Batch Accuracy: 94.801683
# Train		Epoch: 8 	Batch 14/23 (61%) 	Batch Loss: 0.260747 	Batch Accuracy: 94.824219
# Train		Epoch: 8 	Batch 15/23 (65%) 	Batch Loss: 0.250386 	Batch Accuracy: 94.869792
# Train		Epoch: 8 	Batch 16/23 (70%) 	Batch Loss: 0.253107 	Batch Accuracy: 94.946289
# Train		Epoch: 8 	Batch 17/23 (74%) 	Batch Loss: 0.266744 	Batch Accuracy: 94.898897
# Train		Epoch: 8 	Batch 18/23 (78%) 	Batch Loss: 0.248753 	Batch Accuracy: 94.911024
# Train		Epoch: 8 	Batch 19/23 (83%) 	Batch Loss: 0.222503 	Batch Accuracy: 95.014391
# Train		Epoch: 8 	Batch 20/23 (87%) 	Batch Loss: 0.258979 	Batch Accuracy: 94.902344
# Train		Epoch: 8 	Batch 21/23 (91%) 	Batch Loss: 0.242529 	Batch Accuracy: 94.912574
# Train		Epoch: 8 	Batch 22/23 (96%) 	Batch Loss: 0.237953 	Batch Accuracy: 94.912997
# Train		Epoch: 8 	Batch 23/23 (100%) 	Batch Loss: 0.236356 	Batch Accuracy: 94.921875
# 96.17296222664015
# Train		Epoch: 9 	Batch 1/23 (4%) 	Batch Loss: 0.218222 	Batch Accuracy: 97.265625
# Train		Epoch: 9 	Batch 2/23 (9%) 	Batch Loss: 0.208921 	Batch Accuracy: 97.265625
# Train		Epoch: 9 	Batch 3/23 (13%) 	Batch Loss: 0.231422 	Batch Accuracy: 96.484375
# Train		Epoch: 9 	Batch 4/23 (17%) 	Batch Loss: 0.251861 	Batch Accuracy: 95.898438
# Train		Epoch: 9 	Batch 5/23 (22%) 	Batch Loss: 0.214011 	Batch Accuracy: 95.898438
# Train		Epoch: 9 	Batch 6/23 (26%) 	Batch Loss: 0.216097 	Batch Accuracy: 95.768229
# Train		Epoch: 9 	Batch 7/23 (30%) 	Batch Loss: 0.231134 	Batch Accuracy: 95.452009
# Train		Epoch: 9 	Batch 8/23 (35%) 	Batch Loss: 0.211053 	Batch Accuracy: 95.507812
# Train		Epoch: 9 	Batch 9/23 (39%) 	Batch Loss: 0.212981 	Batch Accuracy: 95.464410
# Train		Epoch: 9 	Batch 10/23 (43%) 	Batch Loss: 0.201920 	Batch Accuracy: 95.566406
# Train		Epoch: 9 	Batch 11/23 (48%) 	Batch Loss: 0.223609 	Batch Accuracy: 95.490057
# Train		Epoch: 9 	Batch 12/23 (52%) 	Batch Loss: 0.220164 	Batch Accuracy: 95.475260
# Train		Epoch: 9 	Batch 13/23 (57%) 	Batch Loss: 0.222177 	Batch Accuracy: 95.417668
# Train		Epoch: 9 	Batch 14/23 (61%) 	Batch Loss: 0.199966 	Batch Accuracy: 95.465960
# Train		Epoch: 9 	Batch 15/23 (65%) 	Batch Loss: 0.192687 	Batch Accuracy: 95.533854
# Train		Epoch: 9 	Batch 16/23 (70%) 	Batch Loss: 0.215381 	Batch Accuracy: 95.520020
# Train		Epoch: 9 	Batch 17/23 (74%) 	Batch Loss: 0.193213 	Batch Accuracy: 95.542279
# Train		Epoch: 9 	Batch 18/23 (78%) 	Batch Loss: 0.199235 	Batch Accuracy: 95.529514
# Train		Epoch: 9 	Batch 19/23 (83%) 	Batch Loss: 0.177718 	Batch Accuracy: 95.600329
# Train		Epoch: 9 	Batch 20/23 (87%) 	Batch Loss: 0.181433 	Batch Accuracy: 95.654297
# Train		Epoch: 9 	Batch 21/23 (91%) 	Batch Loss: 0.185067 	Batch Accuracy: 95.684524
# Train		Epoch: 9 	Batch 22/23 (96%) 	Batch Loss: 0.189014 	Batch Accuracy: 95.720881
# Train		Epoch: 9 	Batch 23/23 (100%) 	Batch Loss: 0.162264 	Batch Accuracy: 95.813519
# 96.76938369781313
# Train		Epoch: 10 	Batch 1/23 (4%) 	Batch Loss: 0.191389 	Batch Accuracy: 95.117188
# Train		Epoch: 10 	Batch 2/23 (9%) 	Batch Loss: 0.184591 	Batch Accuracy: 95.410156
# Train		Epoch: 10 	Batch 3/23 (13%) 	Batch Loss: 0.177136 	Batch Accuracy: 95.768229
# Train		Epoch: 10 	Batch 4/23 (17%) 	Batch Loss: 0.181265 	Batch Accuracy: 95.898438
# Train		Epoch: 10 	Batch 5/23 (22%) 	Batch Loss: 0.165015 	Batch Accuracy: 96.210938
# Train		Epoch: 10 	Batch 6/23 (26%) 	Batch Loss: 0.203953 	Batch Accuracy: 96.061198
# Train		Epoch: 10 	Batch 7/23 (30%) 	Batch Loss: 0.160885 	Batch Accuracy: 96.205357
# Train		Epoch: 10 	Batch 8/23 (35%) 	Batch Loss: 0.180017 	Batch Accuracy: 96.166992
# Train		Epoch: 10 	Batch 9/23 (39%) 	Batch Loss: 0.174516 	Batch Accuracy: 96.180556
# Train		Epoch: 10 	Batch 10/23 (43%) 	Batch Loss: 0.187647 	Batch Accuracy: 96.074219
# Train		Epoch: 10 	Batch 11/23 (48%) 	Batch Loss: 0.166936 	Batch Accuracy: 96.129261
# Train		Epoch: 10 	Batch 12/23 (52%) 	Batch Loss: 0.175922 	Batch Accuracy: 96.142578
# Train		Epoch: 10 	Batch 13/23 (57%) 	Batch Loss: 0.152257 	Batch Accuracy: 96.228966
# Train		Epoch: 10 	Batch 14/23 (61%) 	Batch Loss: 0.159481 	Batch Accuracy: 96.289062
# Train		Epoch: 10 	Batch 15/23 (65%) 	Batch Loss: 0.150109 	Batch Accuracy: 96.354167
# Train		Epoch: 10 	Batch 16/23 (70%) 	Batch Loss: 0.172574 	Batch Accuracy: 96.325684
# Train		Epoch: 10 	Batch 17/23 (74%) 	Batch Loss: 0.161322 	Batch Accuracy: 96.346507
# Train		Epoch: 10 	Batch 18/23 (78%) 	Batch Loss: 0.173157 	Batch Accuracy: 96.321615
# Train		Epoch: 10 	Batch 19/23 (83%) 	Batch Loss: 0.153653 	Batch Accuracy: 96.361020
# Train		Epoch: 10 	Batch 20/23 (87%) 	Batch Loss: 0.150121 	Batch Accuracy: 96.396484
# Train		Epoch: 10 	Batch 21/23 (91%) 	Batch Loss: 0.167538 	Batch Accuracy: 96.344866
# Train		Epoch: 10 	Batch 22/23 (96%) 	Batch Loss: 0.165182 	Batch Accuracy: 96.333452
# Train		Epoch: 10 	Batch 23/23 (100%) 	Batch Loss: 0.148967 	Batch Accuracy: 96.356997
# 96.81908548707753
